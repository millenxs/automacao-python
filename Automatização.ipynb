# %%
# !pip install yfinance
# !pip install pyautogui

# %%
import yfinance
import pyautogui

codigo = input("Digite qual a Ticker: ")
dados = yfinance.Ticker(codigo)
dados.history()

tabela = dados.history("6mo")
tabela
# Out:
# Digite qual a Ticker: VALE3.SA
#                                 Open       High        Low      Close  \
# Date
# 2023-07-24 00:00:00-03:00  65.071379  67.589654  64.888761  67.137901
# 2023-07-25 00:00:00-03:00  68.916067  69.838799  68.839178  69.214035
# 2023-07-26 00:00:00-03:00  68.964126  69.444712  68.002953  68.973740
# 2023-07-27 00:00:00-03:00  68.435482  68.473929  67.368579  67.685768
# 2023-07-28 00:00:00-03:00  67.301291  67.301291  65.004089  65.004089
# ...                              ...        ...        ...        ...
# 2024-01-17 00:00:00-03:00  70.269997  70.459999  69.000000  69.349998
# 2024-01-18 00:00:00-03:00  70.199997  70.400002  69.000000  69.000000
# 2024-01-19 00:00:00-03:00  69.500000  69.510002  68.050003  68.099998
# 2024-01-22 00:00:00-03:00  67.500000  67.980003  67.110001  67.800003
# 2024-01-23 00:00:00-03:00  68.949997  69.769997  68.449997  69.199997
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %% [markdown]
# #### Gerar as Analises de Forma Automatica
# - Analise dos ultimos meses
# - cotação minima
# - cotação maxima
# - cotação atual

# %%
maxima = fechamento.max()
minima = fechamento.min()
atual = fechamento[-1]

import pyperclip

# %%
### Enviar um email para o nosso gestor
# abrir uma nova aba no navegador (ctrl + t)

pyautogui.hotkey("ctrl","t") #pressiona a tecla
pyperclip.copy("www.gmail.com.br") #copia o link/texto
pyautogui.hotkey("ctrl","v")
pyautogui.hotkey("enter")
pyautogui.PAUSE = 4

#clicar no botao escrever
pyautogui.click(x=79, y=193)

#colocar o email do destinatario (tab)
pyautogui.click(x=879, y=311)
pyperclip.copy("milenameedeiros@gmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

#colocar o assunto do email (tab)
pyperclip.copy("Analises Diárias")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

#escrever conteudo, f é contatenar 
mensagem = f""" 
Prezado gestor,

Segue as analises diárias dos ultimos seis meses da ação {codigo} 

Cotação Máxima: R$ {round(maxima,2)}
Cotação Minima: R$ {round(minima,2)}
Cotação Atual: R$ {round(atual,2)}

Qualquer dúvida, fico a disposição!"""

pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", "v")

#clicar no botao enviar
pyautogui.click(x=831, y=692)

# %%
import time
time.sleep(7)

pyautogui.position()
# Out:
# Point(x=879, y=311)

# %% [markdown]
# # FRASE DO DIA
# Estou vivendo a minha melhor experiencia de aprendizado
